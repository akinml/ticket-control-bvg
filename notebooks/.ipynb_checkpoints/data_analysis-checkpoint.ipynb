# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta, datetime, date, time, timezone
import datetime as dt

# %%
data = pd.read_csv("data/data20230831.csv")
data = data.copy()

# %% [markdown]
# # Data Analysis

# %%
data.tail(30)
# Out:
#                       date            station_key  \
# 60312  2023-08-17 16:17:25          gesundbrunnen
# 60313  2023-08-17 16:26:06                   alex
# 60314  2023-08-17 16:31:28            lichtenberg
# 60315  2023-08-17 16:33:58              tempelhof
# 60316  2023-08-17 17:24:54                 goerli
# 60317  2023-08-18 05:48:59               wuhletal
# 60318  2023-08-18 07:04:24        frankfurter tor
# 60319  2023-08-18 07:24:58           hauptbahnhof
# 60320  2023-08-18 07:25:20       greifswalder str
# 60321  2023-08-18 07:28:08      landsberger allee
# 60322  2023-08-18 07:32:32       prenzlauer allee
# 60323  2023-08-18 07:54:15        friedrichshagen
# 60324  2023-08-18 08:24:50           hauptbahnhof
# 60325  2023-08-18 08:29:37  platz der luftbruecke
# 60326  2023-08-18 08:30:19              tempelhof
# 60327  2023-08-18 09:15:01        wittenbergplatz
# 60328  2023-08-18 09:17:13                kochstr
# 60329  2023-08-18 09:24:34            mehringdamm
# 60330  2023-08-18 09:28:49            schoeneberg
# 60331  2023-08-18 09:31:35          gesundbrunnen
# 60332  2023-08-18 09:58:07                  rudow
# 60333  2023-08-18 10:04:16          gesundbrunnen
# 60334  2023-08-18 10:27:39       prenzlauer allee
# 60335  2023-08-18 10:39:41          karl marx str
# 60336  2023-08-18 10:52:12          rotes rathaus
# 60337  2023-08-18 11:16:15           hermannplatz
# 60338  2023-08-18 11:28:34         treptower park
# 60339  2023-08-18 11:33:54             beusselstr
# 60340  2023-08-18 12:10:31        friedrichsfelde
# 60341  2023-08-18 12:36:47            mehringdamm
#
#                                                     text  \
# 60312                            2 blau u8 gesundbrunnen
# 60313                     alex beiden herren vordergrund
# 60314      s lichtenberg 1x lange scgatehaare  weisses t
# 60315                                2 kontris tempelhof
# 60316           u3 goerli bahnhof bahnsteig 2 blauwestne
# 60317         2 personen  manl weibl s5 aktuell wuhletal
# 60318  m10 richtung warschauer  gleich frankfurter to...
# 60319  m10 richtung hauptbahnhof gleich landsberger p...
# 60320  0924 uhr  weitergeleitet   s42 greifswalder st...
# 60321  s41 mannlich rote fussball tshirt weblich weis...
# 60322                      prenzlauer s42 steht draussen
# 60323                   m8 klinikum friedrichshain   hbf
# 60324  u5 linden richtung hauptbahnhof blauweissen  b...
# 60325                 u6 gerade platz luftbruecke 3x bos
# 60326        s41 richtung tempelhof poc normal angezogen
# 60327                          3 bos wittenberg platz u2
# 60328                                2 blue west kockstr
# 60329  mehringdamm  beiden wurden dabei gesehen  geld...
# 60330                       s schoeneberg grad 2 kontros
# 60331               2×maennlich 1×weiblich gesundbrunnen
# 60332                  2 blue vests on u7 richtung rudow
# 60333       kontrolle ringbahn gesundbrunnenschoenhauser
# 60334                  s42 prenzlauer allee konto gerade
# 60335  u7 karlmarxstr richtung spandau 4 kontrolleure...
# 60336                          controll u5 rotes rathaus
# 60337  u7 hermannplatz richtung spandau 2 kontrolleur...
# 60338            s42 ringbahn treptower park  3 personen
# 60339                       beusselstr  rotes balenciaga
# 60340                         u5 friedrichsfelde 2x blau
# 60341                             u6 mehringdamm station
#
#                station name                           lines             area  \
# 60312         Gesundbrunnen  U8, S1, S2, S25, S26, S41, S42    Gesundbrunnen
# 60313        Alexanderplatz      U2, U5, U8, S3, S5, S7, S9            Mitte
# 60314           Lichtenberg                 U5, S5, S7, S75      Lichtenberg
# 60315             Tempelhof          U6, S41, S42, S45, S46        Tempelhof
# 60316     Görlitzer Bahnhof                          U1, U3        Kreuzberg
# 60317              Wuhletal                          U5, S5        Kaulsdorf
# 60318       Frankfurter Tor                              U5   Friedrichshain
# 60319          Hauptbahnhof              U5, S3, S5, S7, S9           Moabit
# 60320   Greifswalder Straße               S41, S42, S8, S85   PrenzlauerBerg
# 60321     Landsberger Allee               S41, S42, S8, S85   PrenzlauerBerg
# 60322      Prenzlauer Allee               S41, S42, S8, S85   PrenzlauerBerg
# 60323       Friedrichshagen                              S3  Friedrichshagen
# 60324          Hauptbahnhof              U5, S3, S5, S7, S9           Moabit
# 60325  Platz der Luftbrücke                              U6        Kreuzberg
# 60326             Tempelhof          U6, S41, S42, S45, S46        Tempelhof
# 60327       Wittenbergplatz                      U1, U2, U3       Schöneberg
# 60328            Kochstraße                              U6        Kreuzberg
# 60329           Mehringdamm                          U6, U7        Kreuzberg
# 60330            Schöneberg               S1, S41, S42, S46       Schöneberg
# 60331         Gesundbrunnen  U8, S1, S2, S25, S26, S41, S42    Gesundbrunnen
# 60332                 Rudow                              U7            Rudow
# 60333         Gesundbrunnen  U8, S1, S2, S25, S26, S41, S42    Gesundbrunnen
# 60334      Prenzlauer Allee               S41, S42, S8, S85   PrenzlauerBerg
# 60335      Karl-Marx-Straße                              U7         Neukölln
# 60336         Rotes Rathaus                              U5            Mitte
# 60337          Hermannplatz                          U7, U8         Neukölln
# 60338        Treptower Park           S41, S42, S8, S85, S9      Alt-Treptow
# 60339         Beusselstraße                        S41, S42           Moabit
# 60340       Friedrichsfelde                              U5  Friedrichsfelde
# 60341           Mehringdamm                          U6, U7        Kreuzberg
#
#         latitude  longitude
# 60312  52.548611  13.381250
# 60313  52.521389  13.412639
# 60314  52.510556  13.496389
# 60315  52.470833  13.385278
# 60316  52.499167  13.428056
# 60317  52.512500  13.575000
# 60318  52.515833  13.454167
# 60319  52.525000  13.369444
# 60320  52.540000  13.440556
# 60321  52.529444  13.454722
# 60322  52.544722  13.426111
# 60323  52.457500  13.623333
# 60324  52.525000  13.369444
# 60325  52.485556  13.385833
# 60326  52.470833  13.385278
# 60327  52.501944  13.343056
# 60328  52.505833  13.390556
# 60329  52.494444  13.388611
# 60330  52.479444  13.351667
# 60331  52.548611  13.381250
# 60332  52.416111  13.495278
# 60333  52.548611  13.381250
# 60334  52.544722  13.426111
# 60335  52.476111  13.439167
# 60336  52.518611  13.408333
# 60337  52.487222  13.424722
# 60338  52.493889  13.461389
# 60339  52.534444  13.329444
# 60340  52.506111  13.512778
# 60341  52.494444  13.388611

# %%
data['date'] = pd.to_datetime(data["date"])

# %%
data = data.set_index("date")

# %%
data["area"].value_counts()
# Out:
# Mitte                     10120
# Kreuzberg                  6636
# Neukölln                   5529
# Friedrichshain             5176
# PrenzlauerBerg             4485
#                           ...
# Lehnitz                       3
# Blankenfelde-Mahlow           2
# Borgsdorf                     2
# Fredersdorf-Vogelsdorf        1
# Blankenfelde-Mahl             1
# Name: area, Length: 94, dtype: int64

# %%
areas = data["area"].value_counts()
areas[areas > 300].plot(kind='barh' );

# %%
data["station name"].value_counts()
# Out:
# Alexanderplatz       3170
# Warschauer Straße    1705
# Hermannplatz         1600
# Hermannstraße        1584
# Kottbusser Tor       1570
#                      ...
# Wilhelmshagen           1
# Fredersdorf             1
# Zwickauer Damm          1
# Mahlow                  1
# Neu-Westend             1
# Name: station name, Length: 311, dtype: int64

# %%
station = data["station name"].value_counts()
station[station > 700].plot(kind='barh');

# %%
station[station < 5].plot(kind='barh');

# %%
lines_counts = []
for entries in data["lines"]:
    lines = entries.split(", ")
    for i in lines:
        lines_counts.append(i)

lines_counts = pd.DataFrame(lines_counts)
counts = lines_counts.value_counts()

# %%
lines_counts.value_counts()
# Out:
# S41    17352
# S42    17352
# U8     14298
# S7     13471
# S3     13153
# S9     12868
# S5     12770
# U7      8891
# U6      8593
# S8      8467
# U2      8373
# S85     8346
# U5      7723
# S46     7372
# U3      6983
# U1      6673
# U9      6074
# S1      5370
# S2      5323
# S45     5178
# S26     5061
# S25     4890
# S75     3547
# S47     3107
# U4       550
# dtype: int64

# %%
counts[counts > 1000].plot(kind='barh');

# %%
# Year
# Creating a Year column
data["year"] = data.index
data["year"] = pd.to_datetime(data["year"])
data["year"] = data["year"].dt.year

# Months
# Creating a Month column
data["month"] = data.index
data["month"] = pd.to_datetime(data["month"])
data["month"] = data["month"].dt.month
# Naming the months
months = {
    1: "January", 2: "February", 3: "March", 
    4: "April", 5: "May", 6: "June", 7: "July", 
    8: "August", 9: "September", 10: "October", 
    11: "November", 12: "December"
}
# Applying the naming
data["month"] = data["month"].map(months)

# Weekdays
# Creating a Weekday column
data["weekday"] = data.index
data["weekday"] = pd.to_datetime(data["weekday"])
data["weekday"] = data["weekday"].dt.weekday
# Naming the weekdays
weekdays = {0: "Monday", 1: "Tuesday", 2: "Wednesday", 3: "Thursday", 4: "Friday", 5: "Saturday", 6: "Sunday"}
# Applying the naming
data["weekday"] = data["weekday"].map(weekdays)

# Hours of the day
data["hour"] = data.index
data["hour"] = pd.to_datetime(data["hour"])
data["hour"] = data["hour"].dt.hour

# %%
data["year"].value_counts()
# Out:
# 2021    14363
# 2020    12443
# 2022    11148
# 2019     9504
# 2023     8780
# 2018     4104
# Name: year, dtype: int64

# %%
data["month"].value_counts()
# Out:
# May          6049
# March        5823
# February     5548
# November     5515
# January      5423
# June         5137
# October      5049
# April        4742
# July         4597
# December     4355
# September    4246
# August       3858
# Name: month, dtype: int64

# %%
data["weekday"].value_counts()
# Out:
# Wednesday    11365
# Tuesday      11309
# Thursday     11206
# Monday        9552
# Friday        9280
# Sunday        4017
# Saturday      3613
# Name: weekday, dtype: int64

# %%
data["hour"].value_counts()
# Out:
# 11    6786
# 12    6280
# 10    5826
# 8     5252
# 9     5240
# 13    5126
# 7     4629
# 14    4079
# 15    3386
# 16    3079
# 6     2840
# 17    2628
# 18    1583
# 5     1131
# 19     674
# 20     435
# 21     365
# 22     287
# 4      268
# 23     167
# 0       99
# 3       68
# 1       61
# 2       53
# Name: hour, dtype: int64

# %%
data[data['station_key'] == 'alex'].index = pd.to_datetime(data[data['station_key'] == 'alex'].index)

# %%
data[data['station_key'] == 'alex'].resample('m')['station_key'].count().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
data.resample('w')['station_key'].count().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
data.resample('h')['station_key'].count()
# Out:
# date
# 2018-02-15 12:00:00    1
# 2018-02-15 13:00:00    0
# 2018-02-15 14:00:00    0
# 2018-02-15 15:00:00    0
# 2018-02-15 16:00:00    0
#                       ..
# 2023-08-18 08:00:00    3
# 2023-08-18 09:00:00    6
# 2023-08-18 10:00:00    4
# 2023-08-18 11:00:00    3
# 2023-08-18 12:00:00    2
# Freq: H, Name: station_key, Length: 48241, dtype: int64

# %%
data
# Out:
#                          station_key  \
# date
# 2018-02-15 12:03:54           wildau
# 2018-02-15 18:44:50           erkner
# 2018-02-16 07:39:11      hellersdorf
# 2018-02-16 12:12:04              zoo
# 2018-02-16 14:31:21       beusselstr
# ...                              ...
# 2023-08-18 11:16:15     hermannplatz
# 2023-08-18 11:28:34   treptower park
# 2023-08-18 11:33:54       beusselstr
# 2023-08-18 12:10:31  friedrichsfelde
# 2023-08-18 12:36:47      mehringdamm
#
#                                                                   text  \
# date
# 2018-02-15 12:03:54  https  shopdigitalcouragedelichtbildausweismit...
# 2018-02-15 18:44:50  kritik durchaus berechtigt sehe aba tatsache g...
# 2018-02-16 07:39:11                                             hoelle
# 2018-02-16 12:12:04  s3s5s7s9  berlin hbf  kontrolleure weitergefah...
# 2018-02-16 14:31:21                     beusselstr  s42 glaube beussel
# ...                                                                ...
# 2023-08-18 11:16:15  u7 hermannplatz richtung spandau 2 kontrolleur...
# 2023-08-18 11:28:34            s42 ringbahn treptower park  3 personen
# 2023-08-18 11:33:54                       beusselstr  rotes balenciaga
# 2023-08-18 12:10:31                         u5 friedrichsfelde 2x blau
# 2023-08-18 12:36:47                             u6 mehringdamm station
#
#                             station name                   lines  \
# date
# 2018-02-15 12:03:54               Wildau                     S46
# 2018-02-15 18:44:50               Erkner                      S3
# 2018-02-16 07:39:11          Hellersdorf                      U5
# 2018-02-16 12:12:04  Zoologischer Garten  U2, U9, S3, S5, S7, S9
# 2018-02-16 14:31:21        Beusselstraße                S41, S42
# ...                                  ...                     ...
# 2023-08-18 11:16:15         Hermannplatz                  U7, U8
# 2023-08-18 11:28:34       Treptower Park   S41, S42, S8, S85, S9
# 2023-08-18 11:33:54        Beusselstraße                S41, S42
# 2023-08-18 12:10:31      Friedrichsfelde                      U5
# 2023-08-18 12:36:47          Mehringdamm                  U6, U7
#
#                                 area   latitude  longitude
# date
# 2018-02-15 12:03:54           Wildau  52.320000  13.633889
# 2018-02-15 18:44:50           Erkner  52.429722  13.751389
# 2018-02-16 07:39:11      Hellersdorf  52.536667  13.606389
# 2018-02-16 12:12:04   Charlottenburg  52.507222  13.332500
# 2018-02-16 14:31:21           Moabit  52.534444  13.329444
# ...                              ...        ...        ...
# 2023-08-18 11:16:15         Neukölln  52.487222  13.424722
# 2023-08-18 11:28:34      Alt-Treptow  52.493889  13.461389
# 2023-08-18 11:33:54           Moabit  52.534444  13.329444
# 2023-08-18 12:10:31  Friedrichsfelde  52.506111  13.512778
# 2023-08-18 12:36:47        Kreuzberg  52.494444  13.388611
#
# [60342 rows x 7 columns]

# %% [markdown]
# # Model / Prediction

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
    # df = pd.read_csv('s_u_stations_fixed_with_keys_20230830.csv')  # Replace with the path to your database file
df = data.copy()
stations_full = list(df['keys'].values)
# create a dictionary where U/S bahn line names are the keys and the respective stations are the values incl. lat & lon
output = {'station_key': [], 'line': []}
for idx,row in df.iterrows():
    line_split = row['lines'].split(', ')
    for i in line_split:
        output['station_key'].append(row['keys'])
        output['line'].append(i)
station_to_line = pd.DataFrame(output)
# Out:
#   Cell In [77], line 7
#     line_split = row['lines'].split(', ')
#     ^
# IndentationError: expected an indented block after 'for' statement on line 6

# %% [markdown]
# # Prediction

# %% [markdown]
# # Prediction
