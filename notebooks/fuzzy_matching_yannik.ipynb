# %% [markdown]
# # Fuzzy Matching

# %% [markdown]
# Last update 30.08.2023 Yannik

# %%
import pandas as pd
import re

# %% [markdown]
# ## Uploading the cleaned dataset

# %% [markdown]
# ### Try 1

# %%
# Load your existing database into a DataFrame
data = pd.read_csv('from_yannik/data_clean_with_stopwords.csv') # insert path
# Notice the .copy() to copy the values 
data = data.copy()

# %%
data.reset_index()
data = data[["sender", "text", "date"]]

# %% [markdown]
# ### Try 2

# %%
# Load your existing database into a DataFrame
data2 = pd.read_csv('from_yannik/data_handover_for_anna.csv') # insert path
# Notice the .copy() to copy the values 
data2 = data2.copy()

# %% [markdown]
# ### Try 3

# %%
# Load your existing database into a DataFrame
data3 = pd.read_csv('/home/yannik/ticket-control-bvg/notebooks/data_handover_for_team.csv') # insert path
# Notice the .copy() to copy the values 
data3 = data3.copy()

# %%
data3.head()
# Out:
#    Unnamed: 0       sender                                               text  \
# 0       56130  283284722.0                                                 hä
# 1       45427   21995695.0                                yes ähnliches schon
# 2       84475  462810467.0                                     kanns losgehen
# 3       51061  259910222.0  fahr eigentlich immer schwarz schwerbehinderte...
# 4       87661  489941084.0                                danke fur einladung
#
#                   date
# 0  2018-02-15 11:14:10
# 1  2018-02-15 11:26:54
# 2  2018-02-15 11:29:46
# 3  2018-02-15 11:31:44
# 4  2018-02-15 11:54:57

# %% [markdown]
# ## Preparation: Fuzzy Matching & Stations

# %%
# !pip install thefuzz
# Out:
# Requirement already satisfied: thefuzz in /home/yannik/.pyenv/versions/3.10.6/envs/bvg-project-env/lib/python3.10/site-packages (0.20.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /home/yannik/.pyenv/versions/3.10.6/envs/bvg-project-env/lib/python3.10/site-packages (from thefuzz) (3.2.0)

# %%
from thefuzz import process
from thefuzz import fuzz

# %%
# Upload dataframe with station names
station_df = pd.read_csv('/home/yannik/ticket-control-bvg/notebooks/stations_per_line.csv')
# Creating a list with station names
lines = list(station_df['line'].unique())
sorted_lines = sorted(lines)
sorted_lines
# Out:
# ['S1',
#  'S2',
#  'S25',
#  'S26',
#  'S3',
#  'S41',
#  'S42',
#  'S45',
#  'S46',
#  'S47',
#  'S5',
#  'S7',
#  'S75',
#  'S8',
#  'S85',
#  'S9',
#  'U1',
#  'U2',
#  'U3',
#  'U4',
#  'U5',
#  'U6',
#  'U7',
#  'U8',
#  'U9']

# %% [markdown]
# ## Filters to identify station

# %%
data3.iloc[138649, 2]
# Out:
# 'u7 rudow  steigen gerade bei mehringdamm'

# %%
for line in sorted_lines:
    matches = re.search(r'{line}[^0-9]'.format(line=line.lower()), data3.iloc[138649, 2])
    if matches not None:
        # fuzzy match
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 3), match='u7 '>
# None
# None

# %%
# def identify_line(some_string):
#     res1 = None
#     res2 = None
#     if some_string[1][1] > 70:
#         res1 = some_string[1][0]
#         return some_string[0][0], some_string[1][0]
#     elif some_string[0][1] > 70:
#         return some_string[0][0]
#     return None

# %%
# def identify_line_precise(some_string):
#     res1 = None
#     res2 = None
#     if some_string[1][1] > 90:
#         res1 = some_string[1][0]
#         return some_string[0][0], some_string[1][0]
#     elif some_string[0][1] > 79: #try 79 or 89 and other, better less lines but better quality
#         return some_string[0][0]
#     return None

# %% [markdown]
# # Fuzz Try 1

# %%
line_entries = []
for entries in data["text"]:
    out = process.extract(entries, sorted_lines, limit=2)
    line_entries.append(out)
# Out:
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ',']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!!!!!?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '^^']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '??????????!!!!!!!!!!!!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ';)']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ':)']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '????']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ';)']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '??']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '. .... .... .. ... .....']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+++']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!!!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ':)']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '...?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '^^']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ',']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '...']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!!!!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ',']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!!!!!!!!!!!!!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+ +']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '++']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ', ̈.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+++']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ':)']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ':))))']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???????']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '??']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+++']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '++++++']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '_[']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!!!']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '/']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '++']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ':)']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '???']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '@']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']

# %%
data['fuzz'] = station_entries

# %%
data['station'] = station_entries
data['station'] = data['station'].map(identify_station)

# %%
data.tail(20)
# Out:
#              sender                                               text  \
# 147452  999215014.0  s41 tempelhof und s41 ostkreuz \nfett kontros ...
# 147453  999365610.0                                        immer noch…
# 147454  999365610.0  bvg fährt alles, nur s-bahn & co werden bestreikt
# 147455  999365610.0  sind drin, hinteres ende des zuges. grade mehr...
# 147456  999365610.0  nicht wirklich frei fahren relevant, aber viel...
# 147457  999365610.0  2x ordnungsamt, vorderer teil des zuges am bun...
# 147458  999416326.0                            u6 platz der luftbrücke
# 147459  999425588.0  hallo hätte jemand ein berlin ticket u vom ges...
# 147460  999425588.0  yes got one yesterday at 13:30 would be lovely...
# 147461  999425588.0  hallo hätte jemand ein berlin ticket u vom ges...
# 147462  999425588.0  u 6 keizer augastina black clothes mawhawk and...
# 147463  999425588.0                                        u7 südstern
# 147464  999489207.0  habe ein blanko berlin-pass ticket s ab zu geb...
# 147465  999489207.0  ich habe noch ein blanko berlin ticket s ( für...
# 147466  999510343.0                       2 guys 2 girls u5 weberwiese
# 147467  999684523.0          u2 bei rosalixenburger platz. . 3 manner.
# 147468  999684523.0                          u5 weberwiese. 3-4 manner
# 147469  999684523.0            u2 rosa luxemburg platz. richtung alex.
# 147470  999708285.0  wurde mit 10 uhr ticket um 9 uhr am südstern  ...
# 147471  999708285.0  wurde mit 10 uhr ticket um 9 uhr am südstern  ...
#
#                        date  \
# 147452  2020-11-07 14:56:05
# 147453  2023-03-24 12:45:03
# 147454  2023-03-27 09:27:54
# 147455  2023-04-11 12:18:39
# 147456  2023-04-13 14:53:35
# 147457  2023-05-17 09:43:12
# 147458  2023-07-05 17:13:00
# 147459  2020-08-17 08:03:02
# 147460  2020-08-17 08:20:29
# 147461  2020-08-17 10:48:37
# 147462  2021-01-15 13:07:43
# 147463  2021-02-04 13:32:56
# 147464  2020-06-28 11:19:15
# 147465  2020-06-30 18:26:45
# 147466  2020-06-26 08:22:52
# 147467  2021-03-08 13:48:04
# 147468  2021-03-08 14:52:48
# 147469  2021-04-20 11:53:17
# 147470  2020-06-19 07:45:47
# 147471  2020-06-19 18:18:52
#
#                                                      fuzz  \
# 147452              [(gesundbrunnen, 60), (ostkreuz, 60)]
# 147453                 [(buch, 60), (messe nord/icc, 50)]
# 147454               [(leinestr, 68), (gehrenseestr, 60)]
# 147455            [(mehringdamm, 90), (eichborndamm, 65)]
# 147456  [(mendelssohn bartholdy park, 86), (neukölln, ...
# 147457              [(bundesplatz, 90), (hansaplatz, 63)]
# 147458  [(platz der luftbrücke, 95), (nauener platz, 86)]
# 147459  [(karl bonhoeffer nervenklinik, 86), (karl mar...
# 147460          [(neu westend, 65), (konstanzer str, 51)]
# 147461  [(karl bonhoeffer nervenklinik, 86), (karl mar...
# 147462                     [(tegel, 60), (alt tegel, 57)]
# 147463                     [(südstern, 95), (bernau, 60)]
# 147464             [(heinrich heine str, 57), (buch, 51)]
# 147465  [(kaiserin augusta str, 50), (mühlenbeck mönch...
# 147466                  [(weberwiese, 90), (westend, 60)]
# 147467  [(bayerischer platz, 86), (cottbusser platz, 86)]
# 147468                   [(weberwiese, 90), (erkner, 60)]
# 147469  [(rosa luxemburg platz, 90), (bayerischer plat...
# 147470                   [(südstern, 60), (rehberge, 45)]
# 147471                   [(südstern, 60), (rehberge, 45)]
#
#                                               station
# 147452                                           None
# 147453                                           None
# 147454                                           None
# 147455                                    mehringdamm
# 147456                     mendelssohn bartholdy park
# 147457                                    bundesplatz
# 147458          (platz der luftbrücke, nauener platz)
# 147459  (karl bonhoeffer nervenklinik, karl marx str)
# 147460                                           None
# 147461                   karl bonhoeffer nervenklinik
# 147462                                           None
# 147463                                       südstern
# 147464                                           None
# 147465                                           None
# 147466                                     weberwiese
# 147467          (bayerischer platz, cottbusser platz)
# 147468                                     weberwiese
# 147469      (rosa luxemburg platz, bayerischer platz)
# 147470                                           None
# 147471                                           None

# %% [markdown]
# # Fuzz Try 2 (partial ratio, dataset not fully clean)

# %%
data2.reset_index()
data2 = data2[["sender", "text", "date"]]

# %%
data2.dropna(subset='text', inplace=True)

# %%
data2["text"] = data2["text"].str.strip()

# %%
data2["text"].duplicated().sum()
# Out:
# 8358

# %%
data2 = data2.drop_duplicates(subset='text')

# %%
data2 = data2[data2["text"] != ""]

# %%
data2.dropna(subset='text', inplace=True)

# %%
station_entries2 = []
for entries in data2["text"]:
    out = process.extract(entries, stations, limit=2, scorer=fuzz.partial_ratio)
    station_entries2.append(out)
# Out:
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query:
# 147455           [(mehringdamm, 100), (eichborndamm, 73)]
# 147456                  [(neukölln, 100), (tierpark, 75)]
# 147457              [(bundesplatz, 100), (bundestag, 78)]
# 147459             [(neukölln, 100), (karl marx str, 85)]
# 147460                 [(neu westend, 73), (westend, 71)]
# 147461            [(karl marx str, 100), (neukölln, 100)]
# 147462                    [(tegel, 100), (alt tegel, 67)]
# 147464                   [(buch, 86), (berliner str, 67)]
# 147465                 [(berliner str, 67), (bernau, 67)]
# 147466                 [(weberwiese, 100), (westend, 67)]
# 147467  [(rosa luxemburg platz, 80), (nauener platz, 77)]
# 147468                  [(weberwiese, 100), (erkner, 67)]
# 147469         [(alex, 100), (rosa luxemburg platz, 100)]
# 147470                  [(südstern, 100), (rehberge, 75)]

# %% [markdown]
# ### More precise mapping

# %%
data2['station'] = station_entries2
data2['station'] = data2['station'].map(identify_station_precise)

# %%
data2.tail(30)
# Out:
#              sender                                               text  \
# 147439  999118258.0                          u5 blauwesten hauptbanhof
# 147440  999204625.0  s1 richtung wannsee  1 mann  recht kräftig geb...
# 147441  999204625.0  s1 richtung oranienburg höhe friedrichstraße  ...
# 147442  999204625.0   s1 nach wannsee höhe julius leber  2 frauen  zug
# 147443  999204625.0  s1 friedrichstraße unteren bahnhof  3 männer  ...
# 147444  999204625.0  2 ppl friedrichstraße  2nd one all black clothing
# 147445  999204625.0  2 männer frau kaiser wilhelm platz gerade beid...
# 147446  999204625.0  friedrichstraße direction west s5 direction ch...
# 147447  999204625.0   s1 at friedrichstraße direction north  white bag
# 147448  999215014.0                                           s7 linie
# 147449  999215014.0  hackeschee markt 3 menschen friedrichstraße s1...
# 147450  999215014.0  2 kontros u 6 kochstraße ausgestiegen 2 kontro...
# 147451  999215014.0             polizei rathaus steglitz 1 kontrolleur
# 147452  999215014.0  s41 tempelhof s41 ostkreuz fett kontros bvg si...
# 147453  999365610.0                                        immer noch…
# 147454  999365610.0                     bvg fährt  sbahn  co bestreikt
# 147455  999365610.0       drin  hinteres ende zuges  grade mehringdamm
# 147456  999365610.0  wirklich frei fahren relevant  vielleicht trot...
# 147457  999365610.0  2x ordnungsamt  vorderer teil zuges bundesplat...
# 147459  999425588.0  hallo hätte jemand berlin ticket u gestern 130...
# 147460  999425588.0  yes got one yesterday at 1330 would be lovely ...
# 147461  999425588.0  hallo hätte jemand berlin ticket u gestern 130...
# 147462  999425588.0  u 6 keizer augastina black clothes mawhawk and...
# 147464  999489207.0  blanko berlinpass ticket s ab geben  kaufdatum...
# 147465  999489207.0  blanko berlin ticket s  hartz 4 empf  berlin p...
# 147466  999510343.0                       2 guys 2 girls u5 weberwiese
# 147467  999684523.0            u2 bei rosalixenburger platz   3 manner
# 147468  999684523.0                           u5 weberwiese  34 manner
# 147469  999684523.0             u2 rosa luxemburg platz  richtung alex
# 147470  999708285.0  wurde 10 uhr ticket 9 uhr südstern kontrollier...
#
#                        date                           station  \
# 147465                 [(berliner str, 67), (bernau, 67)]
# 147466                 [(weberwiese, 100), (westend, 67)]
# 147467  [(rosa luxemburg platz, 80), (nauener platz, 77)]
# 147468                  [(weberwiese, 100), (erkner, 67)]
# 147469         [(alex, 100), (rosa luxemburg platz, 100)]
# 147470                  [(südstern, 100), (rehberge, 75)]

# %%
data2.dropna(subset="station", inplace = True)

# %%
data2
# Out:
#               sender                                               text  \
# 2      -1.001571e+12  kontis mehringdamm weiß nich schon sorry   gle...
# 3      -1.001571e+12                                 kontis moritzplatz
# 5      -1.001571e+12  2 kontis u7 nach spandau bei konstanter str au...
# 6      -1.001571e+12  bitte teilen  please spread alerta antifascist...
# 7      -1.001615e+12  großkontrolle u8 schönleibstraße neongelben sc...
# ...              ...                                                ...
# 147466  9.995103e+08                       2 guys 2 girls u5 weberwiese
# 147467  9.996845e+08            u2 bei rosalixenburger platz   3 manner
# 147468  9.996845e+08                           u5 weberwiese  34 manner
# 147469  9.996845e+08             u2 rosa luxemburg platz  richtung alex
# 147470  9.997083e+08  wurde 10 uhr ticket 9 uhr südstern kontrollier...
#
#                        date                       station  \
# 2       2022-03-03 16:41:36        (mehringdamm, spandau)
# 3       2022-03-10 14:38:26                   moritzplatz
# 5       2022-06-12 12:33:58     (spandau, konstanzer str)
# 6       2022-07-14 12:36:03                kottbusser tor
# 7       2021-12-10 22:49:44                  schönleinstr
# ...                     ...                           ...
# 147466  2020-06-26 08:22:52                    weberwiese
# 147467  2021-03-08 13:48:04          rosa luxemburg platz
# 147468  2021-03-08 14:52:48                    weberwiese
# 147469  2021-04-20 11:53:17  (alex, rosa luxemburg platz)
# 147470  2020-06-19 07:45:47                      südstern
#
#                                                      fuzz
# 2                    [(mehringdamm, 100), (spandau, 100)]
# 3                  [(moritzplatz, 100), (hansaplatz, 67)]
# 5                  [(spandau, 100), (konstanzer str, 93)]
# 6                [(kottbusser tor, 100), (bundestag, 78)]
# 7                    [(schönleinstr, 92), (leinestr, 75)]
# ...                                                   ...
# 147466                 [(weberwiese, 100), (westend, 67)]
# 147467  [(rosa luxemburg platz, 80), (nauener platz, 77)]
# 147468                  [(weberwiese, 100), (erkner, 67)]
# 147469         [(alex, 100), (rosa luxemburg platz, 100)]
# 147470                  [(südstern, 100), (rehberge, 75)]
#
# [116659 rows x 5 columns]

# %%
data2.to_csv("preliminary_output_witt_fuzz.csv")

# %% [markdown]
# # Fuzz Try 3

# %%
### below is the code for stations - to be adapted for lines ###

# stations = list(station_df['keys'].values)
# station_entries3 = []
# for entries in data3["text"]:
#     out = process.extract(entries, stations, limit=2, scorer=fuzz.partial_ratio)
#     station_entries3.append(out)

# %%
### code for lines instead of stations ###
sorted_lines
line_entries = []
for entries in data3["text"]:
    out = process.extract(entries, sorted_lines, limit=2, scorer=fuzz.partial_ratio)
    line_entries.append(out)
# Out:
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '̈']

# %%
df_chat = data3[["date"]]

# %%
len(line_entries)
# Out:
# 138650

# %%
df_chat["line_key"] = line_entries
df_chat["text"] = data3["text"]
df_chat["line_key"] = df_chat["line_key"].map(identify_line_precise)
df_chat.dropna(subset="line_key", inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_chat["line_key"] = line_entries
#       2 df_chat["text"] = data3["text"]
#       3 df_chat["line_key"] = df_chat["line_key"].map(identify_line_precise)
#
# File ~/.pyenv/versions/3.10.6/envs/bvg-project-env/lib/python3.10/site-packages/pandas/core/frame.py:3950, in DataFrame.__setitem__(self, key, value)
#    3947     self._setitem_array([key], value)
#    3948 else:
#    3949     # set column
# -> 3950     self._set_item(key, value)
#
# File ~/.pyenv/versions/3.10.6/envs/bvg-project-env/lib/python3.10/site-packages/pandas/core/frame.py:4143, in DataFrame._set_item(self, key, value)
#    4133 def _set_item(self, key, value) -> None:
#    4134     """
#    4135     Add series to DataFrame in specified column.
#    4136
#    (...)
#    4141     ensure homogeneity.
#    4142     """
# -> 4143     value = self._sanitize_column(value)
#    4145     if (
#    4146         key in self.columns
#    4147         and value.ndim == 1
#    4148         and not is_extension_array_dtype(value)
#    4149     ):
#    4150         # broadcast across multiple columns if necessary
#    4151         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/.pyenv/versions/3.10.6/envs/bvg-project-env/lib/python3.10/site-packages/pandas/core/frame.py:4870, in DataFrame._sanitize_column(self, value)
#    4867     return _reindex_for_setitem(Series(value), self.index)
#    4869 if is_list_like(value):
# -> 4870     com.require_length_match(value, self.index)
#    4871 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~/.pyenv/versions/3.10.6/envs/bvg-project-env/lib/python3.10/site-packages/pandas/core/common.py:576, in require_length_match(data, index)
#     572 """
#     573 Check the length of data matches the length of the index.
#     574 """
#     575 if len(data) != len(index):
# --> 576     raise ValueError(
#     577         "Length of values "
#     578         f"({len(data)}) "
#     579         "does not match length of index "
#     580         f"({len(index)})"
#     581     )
#
# ValueError: Length of values (138650) does not match length of index (82170)

# %%
df_chat.reset_index()
# Out:
#         index                 date   line_key  \
# 0          24  2018-02-15 16:47:39  (S2, S25)
# 1          32  2018-02-15 19:25:12         U1
# 2          33  2018-02-15 20:20:00         U1
# 3          42  2018-02-16 12:12:04   (S3, S5)
# 4          43  2018-02-16 12:18:43         U7
# ...       ...                  ...        ...
# 82165  138643  2023-08-18 11:37:53         U7
# 82166  138644  2023-08-18 11:48:39         U2
# 82167  138645  2023-08-18 12:10:31         U5
# 82168  138646  2023-08-18 12:36:47         U6
# 82169  138649  2023-08-18 12:56:43         U7
#
#                                                     text
# 0                   s25 oranienburgerstr  richtung süden
# 1             görli u1  richtung warschauer ausgestiegen
# 2      u1 kurfürstenstrasse richtung uhlandstr tatsäc...
# 3      s3s5s7s9  berlin hbf  kontrolleure weitergefah...
# 4      jmd heute schon westliche u7 langgefahren gesehen
# ...                                                  ...
# 82165             u7 direction rudow at bayrischer platz
# 82166        u2 eberswalder str  bvg sicherheit  polizei
# 82167                         u5 friedrichsfelde 2x blau
# 82168                             u6 mehringdamm station
# 82169           u7 rudow  steigen gerade bei mehringdamm
#
# [82170 rows x 4 columns]

# %%
# Outline for Data analysis

# probability for monday
# probability for day of the week
# probability for time of the day
# probability for seasons
# most occuring stations > check with this for fuzzy match

# aggregate the time object > decompose and do aggregtions
