# %% [markdown]
# # Fuzz Flow

# %%
import pandas as pd
import numpy as np
from datetime import timedelta

# !pip install thefuzz
from thefuzz import process
from thefuzz import fuzz
import re


import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: thefuzz in /Users/annushkak/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (0.20.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /Users/annushkak/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from thefuzz) (3.2.0)

# %%
# Load TELEGRAM DATASET
data3 = pd.read_csv('from_yannik/data_handover_for_team.csv') # insert path
# Notice the .copy() to copy the values 
data3 = data3.copy()

# Load STATIONS DATAFRAME
df = pd.read_csv('s_u_stations_fixed_with_keys_20230830.csv')  # Replace with the path to your database file
# Notice the .copy() to copy the values 
df = df.copy()
stations_full = list(df['keys'].values)

# %%
# create a dictionary where U/S bahn line names are the keys and the respective stations are the values incl. lat & lon
output = {'station_key': [], 'line': []}
for idx,row in df.iterrows():
    line_split = row['lines'].split(', ')    
    for i in line_split:
        output['station_key'].append(row['keys'])
        output['line'].append(i)
station_to_line = pd.DataFrame(output)
station_to_line = station_to_line.drop_duplicates()

lines_un = list(station_to_line['line'].unique())

# %%
def identify_station_precise(some_string, confidence_first=80, confidence_second=90):
    res1 = None
    res2 = None
    if some_string[1][1] > confidence_second:
        res1 = some_string[1][0]
        return some_string[0][0], some_string[1][0]
    elif some_string[0][1] > confidence_first: #try 79 or 89 and other, better less lines but better quality
        return some_string[0][0]
    return None

# %%
def station_finder(some_string):
    for line in lines_un:
        matches = re.search(r'{line}[^0-9]'.format(line=line.lower()), some_string)
        if matches is not None:
            stations = list(station_to_line[station_to_line["line"]==line]["station_key"])
            out = process.extract(some_string, stations, limit=2, scorer=fuzz.partial_ratio)
            return identify_station_precise(out, 70, 70)
    out = process.extract(some_string, stations_full, limit=2, scorer=fuzz.partial_ratio)
    return identify_station_precise(out)

# %%
df_chat = data3[["date"]]

# %%
df_chat["station_key"] = data3["text"].map(station_finder)
# Out:
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '̈']
# /var/folders/13/cyjcpcpx6zx62lkt8r16y6dh0000gn/T/ipykernel_30182/778363400.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chat["station_key"] = data3["text"].map(station_finder)

# %%
df_chat["text"] = data3["text"]
df_chat.dropna(subset="station_key", inplace = True)
# Out:
# /var/folders/13/cyjcpcpx6zx62lkt8r16y6dh0000gn/T/ipykernel_30182/2481860284.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chat["text"] = data3["text"]
# /var/folders/13/cyjcpcpx6zx62lkt8r16y6dh0000gn/T/ipykernel_30182/2481860284.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chat.dropna(subset="station_key", inplace = True)

# %%
df_chat.tail(30)
# Out:
#                        date                      station_key  \
# 138710  2023-08-18 07:55:24            (rudow, hermannplatz)
# 138711  2023-08-18 08:19:21               (alex, strausberg)
# 138712  2023-08-18 08:21:51   (innsbrucker platz, suedkreuz)
# 138713  2023-08-18 08:24:50                     hauptbahnhof
# 138714  2023-08-18 08:29:37            platz der luftbruecke
# 138715  2023-08-18 08:30:19                        tempelhof
# 138716  2023-08-18 08:42:45   (mehringdamm, rathaus spandau)
# 138717  2023-08-18 08:51:48           (mahlsdorf, westkreuz)
# 138718  2023-08-18 08:58:07     (kaulsdorf nord, weberwiese)
# 138719  2023-08-18 08:58:24    (parchimer allee, grenzallee)
# 138720  2023-08-18 09:15:01                  wittenbergplatz
# 138721  2023-08-18 09:17:13                          kochstr
# 138722  2023-08-18 09:23:15  (magdalenenstr, kaulsdorf nord)
# 138723  2023-08-18 09:24:34                      mehringdamm
# 138724  2023-08-18 09:28:49                      schoeneberg
# 138725  2023-08-18 09:31:35                    gesundbrunnen
# 138726  2023-08-18 09:58:07                            rudow
# 138728  2023-08-18 10:04:16                    gesundbrunnen
# 138729  2023-08-18 10:27:39                 prenzlauer allee
# 138730  2023-08-18 10:39:41                    karl marx str
# 138731  2023-08-18 10:52:12                    rotes rathaus
# 138732  2023-08-18 11:16:15                     hermannplatz
# 138733  2023-08-18 11:28:34                   treptower park
# 138735  2023-08-18 11:33:54                       beusselstr
# 138736  2023-08-18 11:37:53       (rudow, bayerischer platz)
# 138737  2023-08-18 11:48:39          (eberswalder str, alex)
# 138738  2023-08-18 12:10:31                  friedrichsfelde
# 138739  2023-08-18 12:36:47                      mehringdamm
# 138741  2023-08-18 12:46:51       (rathaus spandau, spandau)
# 138742  2023-08-18 12:56:43             (mehringdamm, rudow)
#
#                                                      text
# 138710    u7 hermanplazy 4 controller the rudow direction
# 138711               u 5 strausberger platz richtung alex
# 138712  innsbruker platz s42 direction südkreuz 2 more...
# 138713  u5 linden richtung hauptbahnhof blauweissen  b...
# 138714                  u6 gerade platz luftbrücke 3x bos
# 138715        s41 richtung tempelhof poc normal angezogen
# 138716  3 menschen uniform bahnsteig mehringdamm u6 ri...
# 138717  zwei kontrolletis s5 nach westkreuz  gerade ne...
# 138718  u5 richtung kaulsdorf nord  gerade weberwiese ...
# 138719                           2 bos u7 parchimer allee
# 138720                          3 bos wittenberg platz u2
# 138721                                2 blue west kockstr
# 138722  u5 2 blauesten grad magdalenenstr eingestiegen...
# 138723  mehringdamm  beiden wurden dabei gesehen  geld...
# 138724           s schöneberg grad 2 kontros ausgestiegen
# 138725                2×männlich 1×weiblich gesundbrunnen
# 138726              2 blue vests on the u7 richtung rudow
# 138728        kontrolle ringbahn gesundbrunnenschönhauser
# 138729                  s42 prenzlauer allee konto gerade
# 138730  u7 karlmarxstrasse richtung spandau 4 kontroll...
# 138731                          controll u5 rotes rathaus
# 138732  u7 hermannplatz richtung spandau 2 kontrolleur...
# 138733            s42 ringbahn treptower park  3 personen
# 138735                       beusselstr  rotes balenciaga
# 138736             u7 direction rudow at bayrischer platz
# 138737        u2 eberswalder str  bvg sicherheit  polizei
# 138738                         u5 friedrichsfelde 2x blau
# 138739                             u6 mehringdamm station
# 138741                         3 boss   s rathaus spandau
# 138742           u7 rudow  steigen gerade bei mehringdamm

# %%
full_df = df_chat.merge(df, left_on="station_key", right_on="keys")

# %%
full_df = full_df.set_index("date")

# %%
full_df.drop(columns="Unnamed: 0", inplace=True)
full_df.drop(columns="keys", inplace=True)

# %%
full_df = full_df.sort_index(ascending=True)

# %%
full_df.tail(40)
# Out:
#                                station_key  \
# date
# 2023-08-17 12:35:11      landsberger allee
# 2023-08-17 12:44:50               wuhletal
# 2023-08-17 12:49:36             karlshorst
# 2023-08-17 13:11:26           hauptbahnhof
# 2023-08-17 13:20:38          noeldnerplatz
# 2023-08-17 13:50:14               bellevue
# 2023-08-17 14:07:39             hermannstr
# 2023-08-17 14:54:33               ostkreuz
# 2023-08-17 15:01:12               ostkreuz
# 2023-08-17 15:01:31              tempelhof
# 2023-08-17 15:15:14               ostkreuz
